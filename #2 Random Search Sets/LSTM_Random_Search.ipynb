# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time, math, json, os, sys, random

from datetime import datetime
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

import tensorflow as tf
from tensorflow.keras import Sequential, Input, regularizers
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# %%
file_name = ".SEED.txt"
with open(file_name, "r") as file:
    content = file.read().strip()  # Read and remove any extra whitespace/newlines
    number = int(content)  # Use float() to support decimal; use int() if it's always an integer

print("Seed:", number)
print("Type:", type(number))
# Out:
# Seed: 271828183
# Type: <class 'int'>

# %%
# ---------------- User knobs ----------------
CSV_PATH = "ALL_MERGED.csv"     # <--- set your CSV file path
DATE_COL = "Date"
TARGET_COL = "JKSE"
INCLUDE_TARGET_AS_FEATURE = True  # set False to exclude JKSE from X

TEST_SIZE   = 0.20
VAL_SIZE    = 0.10
RANDOM_SEED = number
MAX_EPOCHS  = 100
VERBOSE_TRAIN = 1

# Random search settings
N_TRIALS   = 50           # increase for deeper search (e.g., 30–50)
PATIENCE   = 10           # early stopping patience
WEIGHTS_BEST = "Model Weights/rs_lstm_best.weights.h5"
MODEL_BEST   = "Model Checkpoints/lstm_rs_checkpoint.keras"

print(RANDOM_SEED)
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
os.environ["PYTHONHASHSEED"] = str(RANDOM_SEED)
# Out:
# 271828183

# %%
# ---------------- Load & prep data ----------------
df = pd.read_csv(CSV_PATH)

required = [
    "Date","Nickel_Fut","Coal_Fut_Newcastle","Palm_Oil_Fut",
    "USD_IDR","CNY_IDR","EUR_IDR","BTC_USD",
    "FTSE100","HANGSENG","NIKKEI225","SNP500","DOW30","SSE_Composite","JKSE"
]
missing = [c for c in required if c not in df.columns]
if missing:
    raise ValueError(f"Missing columns: {missing}")

df[DATE_COL] = pd.to_datetime(df[DATE_COL])
df = df.sort_values(DATE_COL).set_index(DATE_COL)

# (Optional) date filtering block if needed
# start_date = pd.Timestamp("2021-01-01")
# end_date   = pd.Timestamp("2025-05-01")
# df = df.loc[(df.index >= start_date) & (df.index <= end_date)].copy()

df = df.ffill().bfill()
df
# Out:
#             Nickel_Fut  Coal_Fut_Newcastle  Palm_Oil_Fut    USD_IDR   CNY_IDR  \
# Date
# 2015-05-01  13750.0000             62.2000          2136 12962.5000 2089.7800
# 2015-05-02  13750.0000             62.2000          2136 12962.5000 2089.7800
# 2015-05-03  13750.0000             62.2000          2136 12962.5000 2089.7800
# 2015-05-04  13750.0000             62.2000          2136 12980.0000 2090.5100
# 2015-05-05  14245.0000             62.5000          2136 13047.5000 2102.3900
# ...                ...                 ...           ...        ...       ...
# 2025-04-27  15482.8800             93.7500          4057 16830.0000 2309.3700
# 2025-04-28  15637.6300             95.6000          3943 16855.0000 2310.5900
# 2025-04-29  15564.0000             97.2500          3911 16760.0000 2305.5200
# 2025-04-30  15342.5000             97.5000          3911 16600.0000 2282.9400
# 2025-05-01  15218.6300             97.5000          3881 16600.0000 2282.9400
#
#               EUR_IDR    BTC_USD   FTSE100   HANGSENG  NIKKEI225    SNP500  \
# Date
# 2015-05-01 14519.9000   232.0790 6986.0000 28123.8203 19531.6309 2108.2900
# 2015-05-02 14519.9000   234.9300 6986.0000 28123.8203 19531.6309 2108.2900
# 2015-05-03 14519.9000   240.3580 6986.0000 28123.8203 19531.6309 2108.2900
# 2015-05-04 14467.5000   239.0180 6986.0000 28123.8203 19531.6309 2114.4900
# 2015-05-05 14594.9000   236.1210 6927.6001 27755.5391 19531.6309 2089.4600
# ...               ...        ...       ...        ...        ...       ...
# 2025-04-27 19127.3000 93754.8438 8415.2998 21980.7402 35705.7383 5525.2100
# 2025-04-28 19251.8000 94978.7500 8417.2998 21971.9609 35839.9883 5528.7500
# 2025-04-29 19082.1000 94284.7891 8463.5000 22008.1094 35839.9883 5560.8301
# 2025-04-30 18805.3000 94207.3125 8494.9004 22119.4102 36045.3789 5569.0601
# 2025-05-01 18745.6000 96492.3359 8496.7998 22119.4102 36452.3008 5604.1401
#
#                 DOW30  SSE_Composite      JKSE
# Date
# 2015-05-01 18024.0605      4480.4639 5140.9370
# 2015-05-02 18024.0605      4480.4639 5140.9370
# 2015-05-03 18024.0605      4480.4639 5140.9370
# 2015-05-04 18070.4004      4480.4639 5140.9370
# 2015-05-05 17928.1992      4298.7061 5160.1074
# ...               ...            ...       ...
# 2025-04-27 40113.5000      3295.0601 6678.9150
# 2025-04-28 40227.5898      3288.4150 6722.9658
# 2025-04-29 40527.6211      3286.6550 6749.0752
# 2025-04-30 40669.3594      3279.0310 6766.7949
# 2025-05-01 40752.9609      3279.0310 6766.7949
#
# [3654 rows x 14 columns]

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df)
plt.title(f"Dataset Plot")
plt.xlabel("Date"); plt.ylabel("Price")
plt.legend(labels=df.columns)
plt.show()

# %%
# ---------------- Split ----------------
n = len(df)
test_n = int(np.floor(TEST_SIZE * n))
trainval_n = n - test_n
val_n = int(np.floor(VAL_SIZE * trainval_n))
train_n = trainval_n - val_n

train_df = df.iloc[:train_n].copy()
val_df   = df.iloc[train_n:train_n + val_n].copy()
test_df  = df.iloc[train_n + val_n:].copy()

print(f"Train: {len(train_df)} ({len(train_df)/len(df)*100:.1f}%) | "
      f"Validation: {len(val_df)} ({len(val_df)/len(df)*100:.1f}%) | "
      f"Test: {len(test_df)} ({len(test_df)/len(df)*100:.1f}%)")
# Out:
# Train: 2632 (72.0%) | Validation: 292 (8.0%) | Test: 730 (20.0%)

# %%
if INCLUDE_TARGET_AS_FEATURE:
    feature_cols = df.columns.tolist()          # includes TARGET_COL (JKSE)
else:
    feature_cols = [c for c in df.columns if c != TARGET_COL]
feature_cols
# Out:
# ['Nickel_Fut',
#  'Coal_Fut_Newcastle',
#  'Palm_Oil_Fut',
#  'USD_IDR',
#  'CNY_IDR',
#  'EUR_IDR',
#  'BTC_USD',
#  'FTSE100',
#  'HANGSENG',
#  'NIKKEI225',
#  'SNP500',
#  'DOW30',
#  'SSE_Composite',
#  'JKSE']

# %%
# ---------------- Scaling (fit only on TRAIN to avoid leakage) ----------------
X_scaler = StandardScaler()
y_scaler = StandardScaler()
X_scaler.fit(train_df[feature_cols])
y_scaler.fit(train_df[[TARGET_COL]])

def scale_block(block):
    X = X_scaler.transform(block[feature_cols])
    y = y_scaler.transform(block[[TARGET_COL]])
    return pd.DataFrame(X, index=block.index, columns=feature_cols), pd.DataFrame(y, index=block.index, columns=[TARGET_COL])

X_train_s, y_train_s = scale_block(train_df)
X_val_s,   y_val_s   = scale_block(val_df)
X_test_s,  y_test_s  = scale_block(test_df)

# %%
# ---------------- Utilities ----------------
def make_windows(X_df, y_df, lookback: int):
    X_vals = X_df.values
    y_vals = y_df.values.squeeze()
    idx = X_df.index

    X_list, y_list, idx_list = [], [], []
    for i in range(lookback, len(X_df)):
        X_list.append(X_vals[i - lookback:i, :])
        y_list.append(y_vals[i])    # predict current step
        idx_list.append(idx[i])
    X_arr = np.array(X_list, dtype=np.float32)
    y_arr = np.array(y_list, dtype=np.float32)
    idx_arr = np.array(idx_list)
    return X_arr, y_arr, idx_arr

def build_model(input_shape, params):
    model = Sequential()
    model.add(Input(shape=input_shape))

    if params["lstm_layers"] == 2:
        model.add(LSTM(params["units1"], return_sequences=True))
        model.add(Dropout(params["dropout"]))
        model.add(LSTM(params["units2"]))
    else:
        model.add(LSTM(params["units1"]))

    model.add(Dropout(params["dropout"]))
    model.add(Dense(1))

    opt = Adam(learning_rate=params["lr"])
    model.compile(optimizer=opt, loss="mse")
    return model

def sample_params():
    params = {
        "lookback": random.choice([30, 45, 60, 90]),
        "lstm_layers": random.choice([1, 2]),
        "units1": random.choice([32, 64, 96, 128, 160, 192, 224, 256]),
        "units2": None,
        "dropout": np.random.uniform(0.0, 0.5),
        "lr": 10 ** np.random.uniform(-4, math.log10(5e-3)),
        "batch_size": random.choice([32, 64, 128]),
        "epochs": random.choice([30, 40, 50, 60, 70, 80, 90, 100]),
        "patience": random.choice([5, 6, 7, 8, 9, 10]),
        "bidirectional": False,       # removed
        "l2_reg": 0.0                 # removed
    }

    if params["lstm_layers"] == 2:
        params["units2"] = random.choice([32, 64, 96, 128, 160, 192, 224, 256])

    return params

def compute_metrics(y_true, y_pred):
    mse  = mean_squared_error(y_true, y_pred)
    mae  = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)
    return [mse, mae, rmse, mape, r2]

# %%
# ---------------- Random Search Loop ----------------
best = {
    "val_loss": np.inf,
    "params": None
}

print("\n=== Random Search begins ===")
hpo_start = time.time()  # HPO timer starts
for t in range(1, N_TRIALS + 1):
    params = sample_params()
    # Window with this trial's lookback
    X_tr, y_tr, _ = make_windows(X_train_s, y_train_s, params["lookback"])
    X_vl, y_vl, _ = make_windows(X_val_s,   y_val_s,   params["lookback"])

    model = build_model((params["lookback"], len(feature_cols)), params)

    callbacks = [
        EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights=True),
    ]

    start = time.time()
    hist = model.fit(
        X_tr, y_tr,
        validation_data=(X_vl, y_vl),
        epochs=params["epochs"],
        batch_size=params["batch_size"],
        callbacks=callbacks,
        verbose=0
    )
    dur = time.time() - start
    val_loss = float(min(hist.history["val_loss"]))

    # Construct units string
    if params["lstm_layers"] == 2:
        units_str = f"[{params['units1']}, {params['units2']}]"
    else:
        units_str = f"[{params['units1']}]"

    print(
        f"[Trial {t:02d}] "
        f"lookback={params['lookback']}, "
        f"layers={params['lstm_layers']}, "
        f"units={units_str}, "
        f"dropout={params['dropout']:.2f}, "
        f"lr={params['lr']:.6f}, "
        f"bs={params['batch_size']}, "
        f"epochs={params['epochs']} "
        f"=> val_loss={val_loss:.6f} ({dur:.1f}s)"
    )

    if val_loss < best["val_loss"]:
        best = {"val_loss": val_loss, "params": params}
        # save a quick snapshot of weights for this trial (optional)
        model.save_weights(WEIGHTS_BEST)
        
hpo_end = time.time()  # HPO timer ends
hpo_time_s = float(hpo_end - hpo_start)
hpo_trials = N_TRIALS

print("\nBest val_loss:", best["val_loss"])
print("Best params:\n", json.dumps(best["params"], indent=2))
# Out:
# === Random Search begins ===
# [Trial 01] lookback=90, layers=1, units=[96], dropout=0.29, lr=0.000602, bs=128, epochs=50 => val_loss=0.070302 (18.9s)
# [Trial 02] lookback=45, layers=1, units=[128], dropout=0.48, lr=0.000804, bs=64, epochs=100 => val_loss=0.016558 (28.7s)
# [Trial 03] lookback=90, layers=1, units=[64], dropout=0.43, lr=0.001776, bs=32, epochs=80 => val_loss=0.011159 (38.5s)
# [Trial 04] lookback=45, layers=2, units=[256, 224], dropout=0.04, lr=0.000659, bs=64, epochs=90 => val_loss=0.046695 (79.4s)
# [Trial 05] lookback=60, layers=1, units=[64], dropout=0.08, lr=0.002324, bs=32, epochs=80 => val_loss=0.018732 (34.0s)
# [Trial 06] lookback=45, layers=2, units=[32, 96], dropout=0.42, lr=0.000152, bs=128, epochs=80 => val_loss=0.183027 (37.0s)
# [Trial 07] lookback=90, layers=2, units=[224, 32], dropout=0.28, lr=0.000114, bs=32, epochs=60 => val_loss=0.023339 (178.3s)
# [Trial 08] lookback=90, layers=2, units=[192, 256], dropout=0.37, lr=0.000775, bs=128, epochs=60 => val_loss=0.010917 (281.3s)
# [Trial 09] lookback=45, layers=1, units=[160], dropout=0.45, lr=0.000172, bs=32, epochs=40 => val_loss=0.038867 (41.9s)
# [Trial 10] lookback=45, layers=2, units=[224, 96], dropout=0.15, lr=0.000117, bs=64, epochs=30 => val_loss=0.057412 (102.7s)
# [Trial 11] lookback=90, layers=2, units=[32, 256], dropout=0.04, lr=0.000127, bs=128, epochs=40 => val_loss=0.210205 (52.7s)
# [Trial 12] lookback=45, layers=1, units=[128], dropout=0.19, lr=0.000323, bs=32, epochs=50 => val_loss=0.030044 (55.7s)
# [Trial 13] lookback=60, layers=1, units=[192], dropout=0.25, lr=0.003255, bs=128, epochs=90 => val_loss=0.008850 (57.6s)
# [Trial 14] lookback=90, layers=1, units=[128], dropout=0.48, lr=0.000610, bs=64, epochs=80 => val_loss=0.015602 (87.7s)
# [Trial 15] lookback=60, layers=1, units=[64], dropout=0.48, lr=0.000176, bs=64, epochs=40 => val_loss=0.189813 (14.8s)
# [Trial 16] lookback=60, layers=1, units=[224], dropout=0.22, lr=0.001893, bs=32, epochs=40 => val_loss=0.005204 (89.9s)
# [Trial 17] lookback=60, layers=2, units=[192, 96], dropout=0.14, lr=0.001959, bs=32, epochs=70 => val_loss=0.005233 (153.7s)
# [Trial 18] lookback=30, layers=2, units=[32, 256], dropout=0.20, lr=0.000985, bs=32, epochs=70 => val_loss=0.028668 (69.9s)
# [Trial 19] lookback=45, layers=2, units=[224, 64], dropout=0.25, lr=0.000403, bs=128, epochs=80 => val_loss=0.028679 (38.6s)
# [Trial 20] lookback=90, layers=1, units=[128], dropout=0.32, lr=0.002372, bs=128, epochs=60 => val_loss=0.008911 (74.0s)
# [Trial 21] lookback=60, layers=2, units=[192, 96], dropout=0.34, lr=0.000337, bs=128, epochs=70 => val_loss=0.059601 (43.3s)
# [Trial 22] lookback=90, layers=2, units=[160, 224], dropout=0.13, lr=0.002745, bs=64, epochs=60 => val_loss=0.004802 (299.0s)
# [Trial 23] lookback=30, layers=1, units=[224], dropout=0.25, lr=0.000378, bs=64, epochs=40 => val_loss=0.015975 (55.0s)
# [Trial 24] lookback=60, layers=1, units=[256], dropout=0.04, lr=0.004501, bs=64, epochs=60 => val_loss=0.007697 (202.1s)
# [Trial 25] lookback=30, layers=2, units=[32, 160], dropout=0.03, lr=0.000380, bs=64, epochs=70 => val_loss=0.067326 (21.6s)
# [Trial 26] lookback=90, layers=2, units=[160, 192], dropout=0.37, lr=0.001990, bs=32, epochs=40 => val_loss=0.004750 (315.6s)
# [Trial 27] lookback=90, layers=1, units=[32], dropout=0.29, lr=0.000852, bs=64, epochs=80 => val_loss=0.041442 (90.4s)
# [Trial 28] lookback=90, layers=2, units=[64, 128], dropout=0.41, lr=0.000140, bs=32, epochs=100 => val_loss=0.030797 (87.7s)
# [Trial 29] lookback=45, layers=1, units=[32], dropout=0.36, lr=0.000585, bs=32, epochs=60 => val_loss=0.042675 (53.0s)
# [Trial 30] lookback=60, layers=2, units=[224, 64], dropout=0.38, lr=0.001194, bs=64, epochs=80 => val_loss=0.027311 (71.0s)
# [Trial 31] lookback=90, layers=1, units=[96], dropout=0.20, lr=0.000415, bs=32, epochs=70 => val_loss=0.011312 (132.1s)
# [Trial 32] lookback=30, layers=2, units=[256, 32], dropout=0.49, lr=0.000715, bs=64, epochs=100 => val_loss=0.036197 (44.8s)
# [Trial 33] lookback=60, layers=1, units=[96], dropout=0.41, lr=0.000413, bs=32, epochs=90 => val_loss=0.086184 (28.6s)
# [Trial 34] lookback=30, layers=2, units=[96, 160], dropout=0.22, lr=0.001241, bs=64, epochs=90 => val_loss=0.027487 (33.2s)
# [Trial 35] lookback=45, layers=2, units=[224, 32], dropout=0.33, lr=0.001009, bs=128, epochs=60 => val_loss=0.038281 (38.0s)
# [Trial 36] lookback=45, layers=1, units=[224], dropout=0.02, lr=0.000221, bs=32, epochs=30 => val_loss=0.081769 (106.7s)
# [Trial 37] lookback=60, layers=2, units=[160, 256], dropout=0.10, lr=0.000140, bs=32, epochs=100 => val_loss=0.042177 (205.0s)
# [Trial 38] lookback=60, layers=1, units=[224], dropout=0.04, lr=0.004810, bs=128, epochs=100 => val_loss=0.008253 (116.6s)
# [Trial 39] lookback=90, layers=1, units=[96], dropout=0.34, lr=0.000939, bs=128, epochs=70 => val_loss=0.035179 (62.9s)
# [Trial 40] lookback=90, layers=1, units=[128], dropout=0.37, lr=0.003660, bs=128, epochs=90 => val_loss=0.009370 (87.2s)
# [Trial 41] lookback=60, layers=2, units=[32, 128], dropout=0.04, lr=0.000186, bs=32, epochs=50 => val_loss=0.276641 (51.2s)
# [Trial 42] lookback=45, layers=2, units=[160, 64], dropout=0.17, lr=0.000116, bs=64, epochs=60 => val_loss=0.055262 (38.8s)
# [Trial 43] lookback=90, layers=2, units=[128, 192], dropout=0.24, lr=0.002797, bs=128, epochs=70 => val_loss=0.010514 (138.2s)
# [Trial 44] lookback=30, layers=2, units=[256, 160], dropout=0.09, lr=0.000207, bs=128, epochs=60 => val_loss=0.036699 (82.1s)
# [Trial 45] lookback=45, layers=2, units=[128, 64], dropout=0.18, lr=0.000198, bs=64, epochs=60 => val_loss=0.085926 (70.9s)
# [Trial 46] lookback=30, layers=1, units=[192], dropout=0.44, lr=0.003714, bs=64, epochs=100 => val_loss=0.009401 (57.3s)
# [Trial 47] lookback=90, layers=1, units=[192], dropout=0.27, lr=0.000121, bs=128, epochs=70 => val_loss=0.022512 (64.5s)
# [Trial 48] lookback=60, layers=2, units=[128, 32], dropout=0.36, lr=0.000281, bs=32, epochs=40 => val_loss=0.123640 (46.2s)
# [Trial 49] lookback=60, layers=2, units=[96, 64], dropout=0.24, lr=0.003978, bs=32, epochs=80 => val_loss=0.014894 (57.5s)
# [Trial 50] lookback=45, layers=2, units=[160, 192], dropout=0.18, lr=0.000347, bs=64, epochs=100 => val_loss=0.049847 (70.8s)
#
# Best val_loss: 0.004750197287648916
# Best params:
#  {
#   "lookback": 90,
#   "lstm_layers": 2,
#   "units1": 160,
#   "units2": 192,
#   "dropout": 0.3665947212008093,
#   "lr": 0.001989780649746322,
#   "batch_size": 32,
#   "epochs": 40,
#   "patience": 7,
#   "bidirectional": false,
#   "l2_reg": 0.0
# }

# %%
# Re-window with best lookback
lb = best["params"]["lookback"]
X_trainval_s = pd.concat([X_train_s, X_val_s], axis=0)
y_trainval_s = pd.concat([y_train_s, y_val_s], axis=0)

X_trv, y_trv, _ = make_windows(X_trainval_s, y_trainval_s, lb)
X_te,  y_te,  idx_te  = make_windows(X_test_s,      y_test_s,      lb)

best_model = build_model((lb, len(feature_cols)), best["params"])

callbacks_final = [
    EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights=True),
    ModelCheckpoint(MODEL_BEST, monitor="val_loss", save_best_only=True),
    # ModelCheckpoint(WEIGHTS_BEST, monitor="val_loss", save_best_only=True, save_weights_only=True)
]

start_train = time.time()
hist_final = best_model.fit(
    X_trv, y_trv,
    validation_split=0.1,   # small split inside train+val to watch overfitting
    epochs=best["params"]["epochs"],
    batch_size=best["params"]["batch_size"],
    callbacks=callbacks_final,
    verbose=VERBOSE_TRAIN
)
end_train = time.time()
print(f"Final training time: {end_train - start_train:.2f} s")
# Out:
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 14s 147ms/step - loss: 0.1670 - val_loss: 0.0523
# Epoch 2/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 146ms/step - loss: 0.0344 - val_loss: 0.0204
# Epoch 3/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 137ms/step - loss: 0.0275 - val_loss: 0.0165
# Epoch 4/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 137ms/step - loss: 0.0239 - val_loss: 0.0130
# Epoch 5/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - loss: 0.0236 - val_loss: 0.0631
# Epoch 6/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - loss: 0.0209 - val_loss: 0.0228
# Epoch 7/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - loss: 0.0226 - val_loss: 0.0241
# Epoch 8/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - loss: 0.0187 - val_loss: 0.0224
# Epoch 9/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - loss: 0.0171 - val_loss: 0.0127
# Epoch 10/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 138ms/step - loss: 0.0208 - val_loss: 0.0095
# Epoch 11/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - loss: 0.0178 - val_loss: 0.0161
# Epoch 12/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - loss: 0.0187 - val_loss: 0.0349
# Epoch 13/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - loss: 0.0169 - val_loss: 0.0304
# Epoch 14/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - loss: 0.0164 - val_loss: 0.0065
# Epoch 15/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 136ms/step - loss: 0.0159 - val_loss: 0.0085
# Epoch 16/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - loss: 0.0165 - val_loss: 0.0097
# Epoch 17/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - loss: 0.0171 - val_loss: 0.0140
# Epoch 18/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - loss: 0.0164 - val_loss: 0.0066
# Epoch 19/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - loss: 0.0147 - val_loss: 0.0108
# Epoch 20/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 136ms/step - loss: 0.0153 - val_loss: 0.0256
# Epoch 21/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - loss: 0.0145 - val_loss: 0.0095
# Epoch 22/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - loss: 0.0148 - val_loss: 0.0062
# Epoch 23/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 134ms/step - loss: 0.0148 - val_loss: 0.0090
# Epoch 24/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - loss: 0.0124 - val_loss: 0.0246
# Epoch 25/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 138ms/step - loss: 0.0155 - val_loss: 0.0100
# Epoch 26/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - loss: 0.0131 - val_loss: 0.0265
# Epoch 27/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - loss: 0.0136 - val_loss: 0.0150
# Epoch 28/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - loss: 0.0135 - val_loss: 0.0095
# Epoch 29/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 137ms/step - loss: 0.0130 - val_loss: 0.0159
# Epoch 30/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 136ms/step - loss: 0.0140 - val_loss: 0.0205
# Epoch 31/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 138ms/step - loss: 0.0131 - val_loss: 0.0059
# Epoch 32/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 138ms/step - loss: 0.0130 - val_loss: 0.0172
# Epoch 33/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - loss: 0.0146 - val_loss: 0.0191
# Epoch 34/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - loss: 0.0128 - val_loss: 0.0283
# Epoch 35/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - loss: 0.0124 - val_loss: 0.0200
# Epoch 36/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - loss: 0.0133 - val_loss: 0.0222
# Epoch 37/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 0.0121 - val_loss: 0.0140
# Epoch 38/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 39/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - loss: 0.0154 - val_loss: 0.0335
# Epoch 40/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0140 - val_loss: 0.0137
# Final training time: 440.60 s

# %%
# Inference
start_test = time.time()
yhat_s = best_model.predict(X_te, verbose=1)
yhat   = y_scaler.inverse_transform(yhat_s).squeeze()
end_test = time.time()
print(f"Testing (inference) time: {end_test - start_test:.4f} s")

# Build actual series aligned to test windows
actual = df[TARGET_COL]
actual_test = actual.loc[idx_te]
pred_test   = pd.Series(yhat, index=idx_te, name="Pred")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
# Testing (inference) time: 1.1791 s

# %%
mse  = mean_squared_error(actual_test.values, pred_test.values)
mae  = mean_absolute_error(actual_test.values, pred_test.values)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(actual_test.values, pred_test.values)
r2   = r2_score(actual_test.values, pred_test.values)

metrics_df = pd.DataFrame(
    [[mse, mae, rmse, mape, r2]],
    columns=["MSE", "MAE", "RMSE", "MAPE", "R²"],
    index=["Test (best cfg)"]
)
pd.set_option("display.float_format", "{:.4f}".format)
print("\n=== Metrics (Final Best Config) ===")
print(metrics_df)
# Out:
# === Metrics (Final Best Config) ===
#                        MSE      MAE     RMSE   MAPE     R²
# Test (best cfg) 24576.6030 127.7952 156.7693 0.0177 0.7791

# %%
residuals = pd.Series(actual_test.values - pred_test.values, index=idx_te, name="Residuals")

# %%
plt.figure(figsize=(12, 5))
plt.plot(actual_test.index, actual_test.values, label="Actual (Test horizon)", linewidth=1.5)
plt.plot(pred_test.index,   pred_test.values,   label="Predicted (Test)", linewidth=1.5)
plt.title("Actual vs Predicted — Test (Best Random Search Config)")
plt.xlabel("Date"); plt.ylabel(TARGET_COL)
plt.legend(); plt.tight_layout(); plt.show()

plt.figure(figsize=(12, 4))
plt.plot(residuals.index, residuals.values, linewidth=1)
plt.axhline(0, linestyle="--", linewidth=1)
plt.title("Residuals Over Time (Test)")
plt.xlabel("Date"); plt.ylabel("Residual = Actual - Predicted")
plt.tight_layout(); plt.show()

plt.figure(figsize=(7, 5))
plt.hist(residuals.values, bins=50, edgecolor="black", alpha=0.8)
plt.title("Residuals Histogram (Test)")
plt.xlabel("Residual"); plt.ylabel("Frequency")
plt.tight_layout(); plt.show()

plt.figure(figsize=(7, 5))
plt.scatter(pred_test.values, residuals.values, s=10, alpha=0.6)
plt.axhline(0, linestyle="--", linewidth=1)
plt.title("Residuals vs Fitted (Test)")
plt.xlabel("Predicted (Fitted)"); plt.ylabel("Residual")
plt.tight_layout(); plt.show()

# Plot final training curve
plt.figure(figsize=(8, 5))
plt.plot(hist_final.history["loss"], label="Train Loss")
plt.plot(hist_final.history["val_loss"], label="Val Loss")
plt.title("Training vs Validation Loss (Best Config)")
plt.xlabel("Epoch"); plt.ylabel("MSE Loss")
plt.legend(); plt.tight_layout(); plt.show()

# %%
# === CONFIGURATION ===
results_dir = os.path.join("..", "Results")
predicted_path = os.path.join(results_dir, "ALL_PREDICTED.csv")
metrics_path = os.path.join(results_dir, "ALL_METRICS.csv")

# Manual model name (since __file__ isn't available in notebooks)
model = "lstm_rs"
model_name = f"{model}_{RANDOM_SEED}"   # change this for each notebook (e.g., GRU_Baseline)
print("Model Name for Documentation:", model_name)

# Create Results directory if not exists
os.makedirs(results_dir, exist_ok=True)

# ==========================================
# 1️⃣ PREPARE AND ALIGN TESTING DATAFRAME
# ==========================================

# Convert dates
test_dates = test_df.index.to_series().reset_index(drop=True)
actual_values = test_df[TARGET_COL].values

# If ALL_PREDICTED doesn't exist, create the base file
if not os.path.exists(predicted_path):
    print("Creating ALL_PREDICTED.csv ...")
    base_df = pd.DataFrame({
        "date": test_dates,
        "actual": actual_values
    })
    base_df.to_csv(predicted_path, index=False)

# Load and ensure datetime consistency
all_pred_df = pd.read_csv(predicted_path)
all_pred_df["date"] = pd.to_datetime(all_pred_df["date"])

# Ensure the file covers full test range (in case it was made from smaller data)
base_df = pd.DataFrame({
    "date": test_dates,
    "actual": actual_values
})
# Outer merge to make sure we have the full timeline
all_pred_df = pd.merge(base_df, all_pred_df, on=["date", "actual"], how="outer")

# Create new prediction column (aligned to date)
pred_series = pd.Series(pred_test.values, index=pd.to_datetime(idx_te), name=model_name)
pred_series = pred_series.reindex(all_pred_df["date"])  # align by date

# Add or update the model column
all_pred_df[model_name] = pred_series.values

# Sort and save
all_pred_df = all_pred_df.sort_values("date").reset_index(drop=True)
all_pred_df.to_csv(predicted_path, index=False)
print(f"✅ Predictions saved to {predicted_path}")

# ==========================================
# 2️⃣ RECORD METRICS SUMMARY
# ==========================================
metrics_columns = [
    "timestamp",
    "model_name", 
    "seed",
    "mse",
    "mae",
    "rmse", 
    "mape",
    "r2_score",
    "picp",
    "mpiw",
    "winkler_score",
    "training_time_s",
    "testing_time_s", 
    "hpo_trial_s",
    "hpo_time_s"
]

# Create ALL_METRICS if missing
if not os.path.exists(metrics_path):
    print("Creating ALL_METRICS.csv ...")
    pd.DataFrame(columns=metrics_columns).to_csv(metrics_path, index=False)

# Current timestamp
timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# Extract metrics
# mse, mae, rmse, mape, r2 = metrics_test
picp = mpiw = winkler = 0

# Build metrics row
metrics_row = {
    "timestamp": timestamp,
    "model_name": model_name,
    "seed": RANDOM_SEED,
    "mse": mse,
    "mae": mae,
    "rmse": rmse,
    "mape": mape,
    "r2_score": r2,
    "picp": picp,
    "mpiw": mpiw,
    "winkler_score": winkler,
    "training_time_s": round(end_train - start_train, 4),
    "testing_time_s": round(end_test - start_test, 4),
    "hpo_trial_s": N_TRIALS,
    "hpo_time_s": round(hpo_end - hpo_start, 4),
}

# Append metrics
all_metrics_df = pd.read_csv(metrics_path)
all_metrics_df = pd.concat([all_metrics_df, pd.DataFrame([metrics_row])], ignore_index=True)
all_metrics_df.to_csv(metrics_path, index=False)
print(f"✅ Metrics appended to {metrics_path}")

print("\n📄 Documentation of predictions and metrics completed successfully.")
# Out:
# Model Name for Documentation: lstm_rs_271828183
# ✅ Predictions saved to ..\Results\ALL_PREDICTED.csv
# ✅ Metrics appended to ..\Results\ALL_METRICS.csv
#
# 📄 Documentation of predictions and metrics completed successfully.
